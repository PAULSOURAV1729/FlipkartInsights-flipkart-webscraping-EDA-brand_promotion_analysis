# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page=1"

# %%
headers=({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36','Accept-Language':'en-US, en;q=0.5'})

# %%
web=requests.get(url,headers=headers)

# %%
web
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(web.text,"lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %% [markdown]
# ## contect scraping

# %%
name=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    for j in mobiles:
        name.append(j.find("div", class_="_4rR01T").text.strip())

# %%
len(name)
# Out:
# 984

# %%
offer_price=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    for j in mobiles:
        element=j.find("div",class_="_30jeq3 _1_WHN1")
        if element is not None:
                text = element.text.strip()
        else:
            text = ''
        offer_price.append(text)

# %%
len(offer_price)
# Out:
# 984

# %%
actual_price=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    for j in mobiles:
        element=j.find("div", class_="_3I9_wc _27UcVY")
        if element is not None:
                text = element.text.strip()
        else:
            text = ''
        actual_price.append(text)

# %%
len(actual_price)
# Out:
# 984

# %%
desc=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    for j in mobiles:
        desc.append(j.find("ul", class_="_1xgFaf").text.strip())
#         if element is not None:
#                 text = element.text.strip()
#         else:
#             text = ''
#         actual_price.append(text)

# %%
len(desc)
# Out:
# 984

# %%
review=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    for j in mobiles:
        element=j.find("div",class_="_3LWZlK")
        if element is not None:
                text = element.text.strip()
        else:
            text = ''
        review.append(text)

# %%
len(review)
# Out:
# 984

# %%
rating_review=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    for j in mobiles:
        element=j.find("span",class_="_2_R_DZ")
        if element is not None:
                text = element.text.strip()
        else:
            text = ''
        rating_review.append(text)

# %%
len(rating_review)
# Out:
# 984

# %%
offer=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    for j in mobiles:
        element = j.find("div", class_="_3Ay6Sb")
        if element is not None:
                text = element.text.strip()
        else:
            text = ''
        offer.append(text)

# %%
len(offer)
# Out:
# 984

# %%
product_links=[]

for i in range(1,100):
    url="https://www.flipkart.com/search?q=smartphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DOnePlus&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.price_range.from%3D20000&p%5B%5D=facets.price_range.to%3DMax&sort=price_asc&page="+str(i)
    web=requests.get(url,headers=headers)
    soup=BeautifulSoup(web.text,"lxml")
    mobiles=soup.find_all("div",class_="_2kHMtA")
    
    links=soup.find_all("a",class_="_1fQZEK")
    l=len(links)
    for j in range(0,l):
        pk=links[j].get("href")
        npk="https://www.flipkart.com"+str(pk)
        product_links.append(npk)

# %%
len(product_links)
# Out:
# 984

# %%
data=pd.DataFrame(list(zip(name,offer_price,actual_price,offer,desc,review,rating_review,product_links)),columns=['Product','Offer_Price','Actual_Price','%Off','Description','Review of 5','Product_Rating','Product_Link'])
data
# Out:
#                                              Product Offer_Price Actual_Price  \
# 0    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)     ₹20,099      ₹21,999
# 1       SAMSUNG Galaxy M33 5G (Emarld Brown, 128 GB)     ₹20,266      ₹24,999
# 2         SAMSUNG Galaxy A33 (Awesome Peach, 128 GB)     ₹20,690      ₹32,990
# 3     SAMSUNG Galaxy M34 5G (Waterfall Blue, 128 GB)     ₹20,890      ₹25,999
# 4     SAMSUNG Galaxy M33 5G (Mystique Green, 128 GB)     ₹20,990      ₹24,999
# ..                                               ...         ...          ...
# 979                   Apple iPhone XS (Gold, 512 GB)   ₹1,34,900
# 980                 Apple iPhone XS (Silver, 512 GB)   ₹1,34,900
# 981             Apple iPhone XS (Space Grey, 512 GB)   ₹1,34,900
# 982    Apple iPhone 14 Pro Max (Space Black, 256 GB)   ₹1,37,999    ₹1,44,900
# 983           Apple iPhone 14 Pro Max (Gold, 256 GB)   ₹1,37,999    ₹1,44,900
#
# ...

# %%
data.to_csv('Flipkart.csv',index=False)
